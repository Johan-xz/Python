# %%
#@title
#trabajo de lunes a domingo
#el pago del primer dia es de 1 centasvo o 0.01 pesos, al siguiente pagan al doble y así sucesivamente
#¿cuanto pagaran en 6 meses?
#cuanto pagaran a los 180 dias
# un mes = 30 dias
dias6 = 30*6
sueldo = 0.01
print("los dias que hay en 6 meses son: ", dias6)
print("por lo tanto son el mismo numero de dias\n")
for dias in range(1,dias6,1):
    sueldo*=2
print("el sueldo a los 6 meses y a los 180 dias es de: ", sueldo,"centavos")
# Out:
# los dias qque hay en 6 meses son:  180
# por lo tanto son el mismo numero de dias
#
# el sueldo a los 6 meses y a los 180 dias es de:  7.662477704329444e+51
