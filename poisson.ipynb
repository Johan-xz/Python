# %%
import numpy as np
from numpy import e
print("Distribución de poisson")
Lambda=int(input("De el valor de lambda (probabilidad que se da en un periodo)= "))
R=int(input("De el valor de R (Valor que quisiera que se diera)= "))
const = pow(e, -Lambda)
print(const)
poiss=0
Fact=1
Vp=0
Sum=0
x=0
for Sum in range (R):
  if(x==0):
    poiss= const*(pow(Lambda, x))
  else:
    Fact= Fact *x
    poiss= const*(pow(Lambda, x))/Fact
  Sum= Sum + poiss
  x=x+1
  Vp=x
  print(Fact)
  print(poiss)
  print(Sum)
print(Vp)
# Out:
# Distribución de poisson
# De el valor de lambda (probabilidad que se da en un periodo)= 4
# De el valor de R (Valor que quisiera que se diera)= 5
# 0.018315638888734186
